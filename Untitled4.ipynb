# %% [markdown]
# <a href="https://colab.research.google.com/github/TaynaraLacerda/Aula-16-04-COMPARADORES-E-OPERADORES/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ATIVIDADE - Operador de comparação

# %%
print('8 é maior que 6: ', 8 > 6)
print('8 é menor que 7: ', 8 < 7)
print('8 é igual a 7: ', 8 == 7)
print("10 é maior ou igual à 10: ", 10 >= 10)
print('10 é menor que 10: ', 10 < 10)
print("10 é menor ou igual á 10:", 10<=10)
# Out:
# 8 é maior que 6:  True
# 8 é menor que 7:  False
# 8 é igual a 7:  False
# 10 é maior ou igual à 10:  True
# 10 é menor que 10:  False
# 10 é menor ou igual á 10: True

# %%
#ATIVIDADE 01

idade1 = int(input("Digite sua idade:  "))
idade2 = int(input("Digite sua idade:  "))
print(idade1 ==idade2)
print(idade1 != idade2)
print(idade1 > idade2)
print(idade1 < idade2)
print(idade1 <= idade2)
# Out:
# Digite sua idade:  25
# Digite sua idade:  30
# False
# True
# False
# True
# True

# %% [markdown]
# Operadores Lógicos

# %%
print("8 é maior que 7 e 7 maior que 8",8 > 7 and 7> 8)
print("8 é maior que 7 e 7 maior que 8: ", 8 > 7 and 7 > 8)
print("8 é maior que 7 ou 7 menor que 8: ", 8 > 7 or 9 < 8)
print("8 é maior que 7 ou 7 menor que 8: ",7 >= 7 or 10<= 10)
# Out:
# 8 é maior que 7 e 7 maior que 8 False
# 8 é maior que 7 e 7 maior que 8:  False
# 8 é maior que 7 ou 7 menor que 8:  True
# 8 é maior que 7 ou 7 menor que 8:  True

# %%
#ATIVIDADE:1-Pode entrar no evento?

idade = int(input("Digite sua idade:  "))
convite = input("Voce tem convite? (sim/nao):")
resultado = (idade >= 18) and (convite == "sim")
print(resultado)
# Out:
# Digite sua idade:  18
# Voce tem convite? (sim/nao):nao
# False

# %%
#Atividade 2 – Acesso ao sistema

usuario = input("Digite o usuário: ")
senha = input("Digite sua senha: ")
resultado = (usuario == "admin") and (senha == "1234")
print(resultado)
# Out:
# Digite o usuário: admin
# Digite sua senha: 1234
# True

# %%
#Atividade 3 – Promoção na Loja

vip = input("Você é cliente VIP? (sim/nao):  ")
compra = float(input("Digite o valor da compra?  "))
resultado = (vip == "sim") or (valor > 100)
print(resultado)
# Out:
# Você é cliente VIP? (sim/nao):  sim
# Digite o valor da compra?  120
# True

# %%
#Atividade 4 – Dia de descanso

dia = input("Digite o dia da semana:  ")
resultado = not(dia == "segunda" or dia == "terça" or dia == "quarta" or dia == "quinta" or dia == "sexta")
print(resultado)
# Out:
# Digite o dia da semana:  segunda
# False
